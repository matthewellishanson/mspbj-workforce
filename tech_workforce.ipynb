# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
techJVS = pd.read_csv('JVS0818.csv')
techJVS.head(30)
# Out:
#    AreaDescription  periodyear  \
# 0        Statewide        2008
# 1        Statewide        2008
# 2        Statewide        2008
# 3        Statewide        2008
# 4        Statewide        2008
# 5        Statewide        2008
# 6        Statewide        2008
# 7        Statewide        2008
# 8   7-County Metro        2008
# 9   7-County Metro        2008
# 10  7-County Metro        2008
# 11  7-County Metro        2008
# 12  7-County Metro        2008
# 13  7-County Metro        2008
# 14  7-County Metro        2008
# 15  7-County Metro        2008
# 16       Statewide        2009
# 17       Statewide        2009
# 18       Statewide        2009
# 19       Statewide        2009
# 20       Statewide        2009
# 21       Statewide        2009
# 22       Statewide        2009
# 23       Statewide        2009
# 24  7-County Metro        2009
# 25  7-County Metro        2009
# 26  7-County Metro        2009
# 27  7-County Metro        2009
# 28  7-County Metro        2009
# ...

# %%
metro = techJVS.loc[(techJVS['AreaDescription'] == '7-County Metro')]
metro.head()
# Out:
#    AreaDescription  periodyear  \
# 8   7-County Metro        2008
# 9   7-County Metro        2008
# 10  7-County Metro        2008
# 11  7-County Metro        2008
# 12  7-County Metro        2008
#
#                                             codetitle  vacancies  vacanrate  \
# 8   Computer Programmers                          ...         79      0.021
# 9   Computer Software Engineers, Applications     ...        430      0.038
# 10  Computer Software Engineers, Systems Software ...         84      0.014
# 11  Computer Support Specialists                  ...        199      0.025
# 12  Computer Systems Analysts                     ...        225      0.037
#
#     medianwage
# 8        27.07
# 9        26.59
# 10       28.83
# 11       19.03
# 12       27.40

# %%
state = techJVS.loc[(techJVS['AreaDescription'] == 'Statewide')]
state.head()
# Out:
#   AreaDescription  periodyear  \
# 0       Statewide        2008
# 1       Statewide        2008
# 2       Statewide        2008
# 3       Statewide        2008
# 4       Statewide        2008
#
#                                            codetitle  vacancies  vacanrate  \
# 0  Computer Programmers                          ...        119      0.021
# 1  Computer Software Engineers, Applications     ...        445      0.028
# 2  Computer Software Engineers, Systems Software ...         96      0.011
# 3  Computer Support Specialists                  ...        234      0.019
# 4  Computer Systems Analysts                     ...        244      0.029
#
#    medianwage
# 0       25.38
# 1       26.58
# 2       28.91
# 3       18.70
# 4       27.12

# %%
metro['vacancies_percentchange'] = metro.groupby('codetitle')['vacancies'].pct_change()
metro
# Out:
# /Users/mhanson/anaconda3/envs/mspbj/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     AreaDescription  periodyear  \
# 8    7-County Metro        2008
# 9    7-County Metro        2008
# 10   7-County Metro        2008
# 11   7-County Metro        2008
# 12   7-County Metro        2008
# 13   7-County Metro        2008
# 14   7-County Metro        2008
# 15   7-County Metro        2008
# 24   7-County Metro        2009
# 25   7-County Metro        2009
# 26   7-County Metro        2009
# 27   7-County Metro        2009
# 28   7-County Metro        2009
# 29   7-County Metro        2009
# 30   7-County Metro        2009
# ...

# %%
state['vacancies_percentchange'] = state.groupby('codetitle')['vacancies'].pct_change()
state
# Out:
# /Users/mhanson/anaconda3/envs/mspbj/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     AreaDescription  periodyear  \
# 0         Statewide        2008
# 1         Statewide        2008
# 2         Statewide        2008
# 3         Statewide        2008
# 4         Statewide        2008
# 5         Statewide        2008
# 6         Statewide        2008
# 7         Statewide        2008
# 16        Statewide        2009
# 17        Statewide        2009
# 18        Statewide        2009
# 19        Statewide        2009
# 20        Statewide        2009
# 21        Statewide        2009
# 22        Statewide        2009
# ...
